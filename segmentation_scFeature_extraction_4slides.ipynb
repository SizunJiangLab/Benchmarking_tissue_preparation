# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepcell==0.12.10 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.12.10)
# Collecting imagecodecs==2024.6.1
#   Downloading imagecodecs-2024.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.6 MB)
#      |████████████████████████████████| 39.6 MB 2.4 MB/s eta 0:00:01     |███████████████                 | 18.5 MB 2.4 MB/s eta 0:00:09     |█████████████████▊              | 22.0 MB 2.4 MB/s eta 0:00:08     |█████████████████████           | 26.0 MB 2.4 MB/s eta 0:00:06
# Requirement already satisfied: numpy==1.26.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: pandas==2.2.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: scikit-image==0.24.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.24.0)
# Requirement already satisfied: tensorflow==2.8.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.8.4)
# Requirement already satisfied: pydot<2,>=1.4.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: scipy<2,>=1.2.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: deepcell-tracking~=0.6.5 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (0.6.5)
# Requirement already satisfied: deepcell-toolbox>=0.12.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: opencv-python-headless<5 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (4.10.0.84)
# Requirement already satisfied: spektral~=1.0.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (1.0.6)
# Requirement already satisfied: matplotlib in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (3.9.2)
# Requirement already satisfied: jupyter<2,>=1.0.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: tensorflow-addons~=0.16.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (0.16.1)
# Requirement already satisfied: tqdm in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (4.66.5)
# Requirement already satisfied: scikit-learn>=0.20.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell==0.12.10->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from pandas==2.2.2->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from pandas==2.2.2->-r requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from pandas==2.2.2->-r requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: imageio>=2.33 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-image==0.24.0->-r requirements.txt (line 5)) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-image==0.24.0->-r requirements.txt (line 5)) (2024.8.28)
# Requirement already satisfied: pillow>=9.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-image==0.24.0->-r requirements.txt (line 5)) (10.4.0)
# Requirement already satisfied: packaging>=21 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-image==0.24.0->-r requirements.txt (line 5)) (24.1)
# Requirement already satisfied: networkx>=2.8 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-image==0.24.0->-r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: lazy-loader>=0.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-image==0.24.0->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: astunparse>=1.6.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /apps/python/3.9-2022.05/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.66.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.37.1)
# Requirement already satisfied: setuptools in /apps/python/3.9-2022.05/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (61.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (3.11.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: libclang>=9.0.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (18.1.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: flatbuffers>=1.12 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (24.3.25)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /apps/python/3.9-2022.05/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.37.1)
# Requirement already satisfied: cython<3.0,>=0.28.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from deepcell-toolbox>=0.12.1->deepcell==0.12.10->-r requirements.txt (line 1)) (0.29.37)
# Requirement already satisfied: jupyter-console in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (7.16.4)
# Requirement already satisfied: ipykernel in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: ipywidgets in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (8.1.5)
# Requirement already satisfied: notebook in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: jupyterlab in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (4.2.5)
# Requirement already satisfied: pyparsing>=2.1.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from pydot<2,>=1.4.2->deepcell==0.12.10->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-learn>=0.20.4->deepcell==0.12.10->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from scikit-learn>=0.20.4->deepcell==0.12.10->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: lxml in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from spektral~=1.0.4->deepcell==0.12.10->-r requirements.txt (line 1)) (5.3.0)
# Requirement already satisfied: requests in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from spektral~=1.0.4->deepcell==0.12.10->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (2.34.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: zipp>=0.5 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.20.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r requirements.txt (line 1)) (3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: typeguard>=2.7 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from tensorflow-addons~=0.16.1->deepcell==0.12.10->-r requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (2.1.5)
# Requirement already satisfied: comm>=0.1.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (8.6.2)
# Requirement already satisfied: debugpy>=1.6.5 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.8.5)
# Requirement already satisfied: pyzmq>=24 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (26.2.0)
# Requirement already satisfied: traitlets>=5.4.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: nest-asyncio in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: ipython>=7.23.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (8.18.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: psutil in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: tornado>=6.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: decorator in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: pygments>=2.4.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: pexpect>4.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: stack-data in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: exceptiongroup in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (3.0.47)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipywidgets->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (3.0.13)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from ipywidgets->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (4.0.13)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.27.3)
# Requirement already satisfied: tomli>=1.2.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: async-lru>=1.0.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.14.2)
# Requirement already satisfied: notebook-shim>=0.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: jinja2>=3.0.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: httpx>=0.25.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.27.2)
# Requirement already satisfied: httpcore==1.* in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: sniffio in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: anyio in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: websocket-client>=1.7 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: argon2-cffi>=21.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: overrides>=5.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: argon2-cffi-bindings in /apps/python/3.9-2022.05/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: referencing in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: pyyaml>=5.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rpds-py>=0.7.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: attrs>=22.2.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: isoduration in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: webcolors>=24.6.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (24.8.0)
# Requirement already satisfied: jsonpointer>1.13 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: fqdn in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: uri-template in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: json5>=0.9.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.9.25)
# Requirement already satisfied: babel>=2.10 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.16.0)
# Requirement already satisfied: nbclient>=0.5.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: beautifulsoup4 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (4.12.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: bleach!=5.0.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: tinycss2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: jupyterlab-pygments in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: defusedxml in /apps/python/3.9-2022.05/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: webencodings in /apps/python/3.9-2022.05/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: pycparser in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.6)
# Requirement already satisfied: arrow>=0.15.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.9.0.20240821)
# Requirement already satisfied: cycler>=0.10 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from matplotlib->deepcell==0.12.10->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from matplotlib->deepcell==0.12.10->-r requirements.txt (line 1)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from matplotlib->deepcell==0.12.10->-r requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from matplotlib->deepcell==0.12.10->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from matplotlib->deepcell==0.12.10->-r requirements.txt (line 1)) (6.4.4)
# Requirement already satisfied: asttokens>=2.1.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: pure-eval in /users/PCON0100/feng1426/.local/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r requirements.txt (line 1)) (0.2.3)
# Installing collected packages: imagecodecs
#   WARNING: The script imagecodecs is installed in '/users/PCON0100/feng1426/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed imagecodecs-2024.6.1

# %%
import os
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"]="3" # specify visible gpu(s), can check gpu usage in terminal using 'nvidia-smi'

try:
    tf_gpus = tf.config.list_physical_devices('GPU')
    for gpu in tf_gpus:
        tf.config.experimental.set_memory_growth(gpu, True) # allow memory growth on visible gpu(s)
except:
    pass
# Out:
# /users/PCON0100/feng1426/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /users/PCON0100/feng1426/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
# 2024-09-03 09:52:28.945762: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-09-03 09:52:28.945844: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: p0254.ten.osc.edu
# 2024-09-03 09:52:28.945867: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: p0254.ten.osc.edu
# 2024-09-03 09:52:28.946013: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 535.104.5
# 2024-09-03 09:52:28.946081: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 535.104.5
# 2024-09-03 09:52:28.946098: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 535.104.5

# %%
import matplotlib.pyplot as plt # for plotting images

from tifffile import tifffile

import numpy as np
import pandas as pd
import glob
from skimage.io import imsave
from skimage import img_as_ubyte
import skimage 
import skimage.io
import skimage.measure
import skimage.morphology
from tqdm import tqdm

from deepcell.applications import Mesmer # Mesmer
from deepcell.utils.plot_utils import create_rgb_image, make_outline_overlay

from pylibs.tissue_preparation import (
    read_qtiff_image,
    generate_nuclear_and_membrane,
    stack_nuclear_and_membrane,
    run_segmentation,
    extract_sc_features,
)

# %%
os.environ["DATA_FOLDER"] = "/fs/scratch/PCON0100/feng1426/temp/Benchmarking_tissue_preparation_data/"
os.environ["OUT_FOLDER"] = "/fs/scratch/PCON0100/feng1426/temp/Benchmarking_tissue_preparation_out/"

# %%
data_folder = os.environ.get("DATA_FOLDER", "./data/")
out_folder = os.environ.get("OUT_FOLDER", "./out/")

# %% [markdown]
# ## Segmentation

# %%
# open the image and check dimensions
slide1 = read_qtiff_image(f'{data_folder}Slide 1_20 min HIER 1h RT stain_Scan1.qptiff')
slide1.shape
# Out:
# (28, 21600, 26880)

# %%
slide2 = read_qtiff_image(f'{data_folder}Slide 2_20 min HIER on 4C stain_Scan1.qptiff')
slide2.shape
# Out:
# (28, 16560, 24960)

# %%
slide3 = read_qtiff_image(f'{data_folder}Slide 3_10 min HIER on 4C stain_Scan1.qptiff')
slide3.shape
# Out:
# (28, 25200, 33600)

# %%
slide4 = read_qtiff_image(f'{data_folder}Slide 4_40 min HIER on 4C stain_Scan1.qptiff')
slide4.shape
# Out:
# (28, 22320, 25920)

# %% [markdown]
# Dimensions of the image array are (11, 17280, 24960), meaning it is a 3D stack of 2D image arrays (11 channels of 17280 x 24960 images).
#
# The order of the channels should match the order when you open the qptiff in QuPath for example (C1 in QuPath = first index here, C2 in QuPath = second index here, etc). But also always good to double check

# %%
# use this to check which marker is which index in the qptiff
# indexing in python starts at 0 not at 1 like in R, so [0, :, :] = C1 in the qptiff
plt.figure(figsize = (5, 5))
plt.imshow(slide1[0, :, :]);

plt.figure(figsize = (5, 5))
plt.imshow(slide2[0, :, :]);

plt.figure(figsize = (5, 5))
plt.imshow(slide3[0, :, :]);

plt.figure(figsize = (5, 5))
plt.imshow(slide4[0, :, :]);

# 0 = DAPI
# 1 = CD3
# 2 = aSMA
# 3 = CD15
# 4 = CD4
# 5 = CD8
# 6 = CD11b
# 7 = CD11c
# 8 = CD20
# 9 = CCD21
# 10 = CH2K27me3
# 11 = Ki-67
# 12 = HLA-DRAta_folder}
# 13 = Histone H3
# 14 = CD68
# 15 = DC-SIGN
# 16 = Foxp3
# 17 = PD-1
# 18 = CD163
# 19 = H3K27ac
# 20 = Granzyme B
# 21 = CD31
# 22 = CD206
# 23 = 138
# 24 = NaK ATPase
# 25 = CD45RA
# 26 = CD45
# 27 = Cytokeratin

# %%
nuclear1, membrane1 = generate_nuclear_and_membrane(slide1)
    
nuclear2, membrane2 = generate_nuclear_and_membrane(slide2)

nuclear3, membrane3 = generate_nuclear_and_membrane(slide3)

nuclear4, membrane4 = generate_nuclear_and_membrane(slide4)

# %%
# show the final nuclear and membrane arrays as images
fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(nuclear1)
ax[1].imshow(membrane1)

ax[0].set_title('nuclear1')
ax[1].set_title('membrane1')
# Out:
# Text(0.5, 1.0, 'membrane1')

# %%
# show the final nuclear and membrane arrays as images
fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(nuclear2)
ax[1].imshow(membrane2)

ax[0].set_title('nuclear2')
ax[1].set_title('membrane2')
# Out:
# Text(0.5, 1.0, 'membrane2')

# %%
# show the final nuclear and membrane arrays as images
fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(nuclear3)
ax[1].imshow(membrane3)

ax[0].set_title('nuclear3')
ax[1].set_title('membrane3')
# Out:
# Text(0.5, 1.0, 'membrane3')

# %%
# show the final nuclear and membrane arrays as images
fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(nuclear4)
ax[1].imshow(membrane4)

ax[0].set_title('nuclear4')
ax[1].set_title('membrane4')
# Out:
# Text(0.5, 1.0, 'membrane4')

# %%
# save nuclear and membrane tiffs for future reference 
# (can also check that nuclear is actually nuclear by opening the image, hard to tell in a python notebook)
imsave(f"{out_folder}MESMER_outputs/nuclear1.tiff", nuclear1, check_contrast = False)
imsave(f"{out_folder}MESMER_outputs/membrane1.tiff", membrane1, check_contrast = False)

# %%
# save nuclear and membrane tiffs for future reference 
# (can also check that nuclear is actually nuclear by opening the image, hard to tell in a python notebook)
imsave(f"{out_folder}MESMER_outputs/nuclear2.tiff", nuclear2, check_contrast = False)
imsave(f"{out_folder}MESMER_outputs/membrane2.tiff", membrane2, check_contrast = False)

# %%
# save nuclear and membrane tiffs for future reference 
# (can also check that nuclear is actually nuclear by opening the image, hard to tell in a python notebook)
imsave(f"{out_folder}MESMER_outputs/nuclear3.tiff", nuclear3, check_contrast = False)
imsave(f"{out_folder}MESMER_outputs/membrane3.tiff", membrane3, check_contrast = False)

# %%
# save nuclear and membrane tiffs for future reference 
# (can also check that nuclear is actually nuclear by opening the image, hard to tell in a python notebook)
imsave(f"{out_folder}MESMER_outputs/nuclear4.tiff", nuclear4, check_contrast = False)
imsave(f"{out_folder}MESMER_outputs/membrane4.tiff", membrane4, check_contrast = False)

# %%
# stack the nuclear and membrane arrays we created
stack1 = stack_nuclear_and_membrane(nuclear=nuclear1, membrane=membrane1)
stack1.shape
# Out:
# (1, 21600, 26880, 2)

# %%
# stack the nuclear and membrane arrays we created
stack2 = stack_nuclear_and_membrane(nuclear=nuclear2, membrane=membrane2)
stack2.shape
# Out:
# (1, 16560, 24960, 2)

# %%
# stack the nuclear and membrane arrays we created
stack3 = stack_nuclear_and_membrane(nuclear=nuclear3, membrane=membrane3)
stack3.shape
# Out:
# (1, 25200, 33600, 2)

# %%
# stack the nuclear and membrane arrays we created
stack4 = stack_nuclear_and_membrane(nuclear=nuclear4, membrane=membrane4)
stack4.shape
# Out:
# (1, 22320, 25920, 2)

# %%
y_min1 = 9500
y_max1 = 15000
x_min1 = 5000
x_max1 = 12000

# %%
# crop out area of interest

fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(stack1[0, :, :, 0])
ax[1].imshow(stack1[0, y_min1:y_max1, x_min1:x_max1, 0])

ax[0].set_title('full1')
ax[1].set_title('cropped1')
# Out:
# Text(0.5, 1.0, 'cropped1')

# %%
y_min2 = 4000
y_max2 = 9500
x_min2 = 3000
x_max2 = 10000

# %%
# crop out area of interest


fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(stack2[0, :, :, 0])
ax[1].imshow(stack2[0, y_min2:y_max2, x_min2:x_max2, 0])

ax[0].set_title('full2')
ax[1].set_title('cropped2')
# Out:
# Text(0.5, 1.0, 'cropped2')

# %%
y_min3 = 5500
y_max3 = 11000
x_min3 = 8600
x_max3 = 15600

# %%
# crop out area of interest


fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(stack3[0, :, :, 0])
ax[1].imshow(stack3[0, y_min3:y_max3, x_min3:x_max3, 0])

ax[0].set_title('full3')
ax[1].set_title('cropped3')
# Out:
# Text(0.5, 1.0, 'cropped3')

# %%
y_min4 = 9600
y_max4 = 15100
x_min4 = 3200
x_max4 = 10200

# %%
# crop out area of interest


fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(stack4[0, :, :, 0])
ax[1].imshow(stack4[0, y_min4:y_max4, x_min4:x_max4, 0])

ax[0].set_title('full4')
ax[1].set_title('cropped4');

# %%
cropped_stack1 = stack1[:, y_min1:y_max1, x_min1:x_max1, :]
cropped_stack1.shape
# Out:
# (1, 5500, 7000, 2)

# %%
cropped_stack2 = stack2[:, y_min2:y_max2, x_min2:x_max2, :]
cropped_stack2.shape
# Out:
# (1, 5500, 7000, 2)

# %%
cropped_stack3 = stack3[:, y_min3:y_max3, x_min3:x_max3, :]
cropped_stack3.shape
# Out:
# (1, 5500, 7000, 2)

# %%
cropped_stack4 = stack4[:, y_min4:y_max4, x_min4:x_max4, :]
cropped_stack4.shape
# Out:
# (1, 5500, 7000, 2)

# %%
# these are the Mesmer default parameters for reference:
# default_kwargs_cell = {
#             'maxima_threshold': 0.075,
#             'maxima_smooth': 0,
#             'interior_threshold': 0.2,
#             'interior_smooth': 2,
#             'small_objects_threshold': 15,
#             'fill_holes_threshold': 15,
#             'radius': 2
#         }

# MESMER PARAMETERS
# mpp = microns per pixel resolution, should be static based on experiment
# I believe the phenoimager resolution is advertised as 0.5 mpp at 20x but you guys probably know better than me
image_mpp = 0.50

# maxima_threshold controls what is considered a unique cell (lower values = more separate cells, higher values = fewer cells)
# interior_threshold determines what is considered background/not part of a cell (lower value = larger cells)
maxima_threshold = 0.075
interior_threshold = 0.2

# %%
# %%time

# run segmentation
predictions1 = run_segmentation(cropped_stack1)
# Out:
# INFO:root:Checking for cached data
# INFO:root:Checking MultiplexSegmentation-9.tar.gz against provided file_hash...
# INFO:root:MultiplexSegmentation-9.tar.gz with hash a1dfbce2594f927b9112f23a0a1739e0 already available.
# INFO:root:Extracting /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz
# INFO:root:Successfully extracted /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz into /users/PCON0100/feng1426/.deepcell/models
# 2024-09-03 10:04:56.231147: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /users/PCON0100/feng1426/.local/lib/python3.9/site-packages/deepcell_toolbox/deep_watershed.py:108: UserWarning: h_maxima peak finding algorithm was selected, but the provided image is larger than 5k x 5k pixels.This will lead to slow prediction performance.
#   warnings.warn('h_maxima peak finding algorithm was selected, '
# CPU times: user 15min 10s, sys: 7min 49s, total: 23min
# Wall time: 5min 10s

# %%
# %%time

# run segmentation
predictions2 = run_segmentation(cropped_stack2)
# Out:
# INFO:root:Checking for cached data
# INFO:root:Checking MultiplexSegmentation-9.tar.gz against provided file_hash...
# INFO:root:MultiplexSegmentation-9.tar.gz with hash a1dfbce2594f927b9112f23a0a1739e0 already available.
# INFO:root:Extracting /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz
# INFO:root:Successfully extracted /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz into /users/PCON0100/feng1426/.deepcell/models
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# CPU times: user 15min 5s, sys: 8min, total: 23min 5s
# Wall time: 5min 7s

# %%
# %%time

# run segmentation
predictions3 = run_segmentation(cropped_stack3)
# Out:
# INFO:root:Checking for cached data
# INFO:root:Checking MultiplexSegmentation-9.tar.gz against provided file_hash...
# INFO:root:MultiplexSegmentation-9.tar.gz with hash a1dfbce2594f927b9112f23a0a1739e0 already available.
# INFO:root:Extracting /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz
# INFO:root:Successfully extracted /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz into /users/PCON0100/feng1426/.deepcell/models
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# CPU times: user 15min 9s, sys: 8min 3s, total: 23min 12s
# Wall time: 5min 11s

# %%
# %%time

# run segmentation
predictions4 = run_segmentation(cropped_stack4)
# Out:
# INFO:root:Checking for cached data
# INFO:root:Checking MultiplexSegmentation-9.tar.gz against provided file_hash...
# INFO:root:MultiplexSegmentation-9.tar.gz with hash a1dfbce2594f927b9112f23a0a1739e0 already available.
# INFO:root:Extracting /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz
# INFO:root:Successfully extracted /users/PCON0100/feng1426/.deepcell/models/MultiplexSegmentation-9.tar.gz into /users/PCON0100/feng1426/.deepcell/models
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# CPU times: user 15min 5s, sys: 8min 1s, total: 23min 6s
# Wall time: 5min 7s

# %%
rgb_image = create_rgb_image(cropped_stack1, channel_colors = ["green", "blue"])
overlay = make_outline_overlay(rgb_data = rgb_image, predictions = predictions1)

# save MESMER outputs
output_dir = f'{out_folder}MESMER_outputs/{maxima_threshold}maxima_1_{interior_threshold}interior_1/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

skimage.io.imsave(output_dir + "seg_outline1.tiff", img_as_ubyte(overlay[0, ..., 0]), check_contrast = False) # segmentation outline
skimage.io.imsave(output_dir + "seg_overlay1.tiff", img_as_ubyte(overlay[0, ...]), check_contrast = False) # segmentation overlay (nuc + membrane + outline)
skimage.io.imsave(output_dir + "MESMER_mask1.tiff", predictions1[0, ..., 0], check_contrast = False) # MESMER mask

# %%
rgb_image = create_rgb_image(cropped_stack2, channel_colors = ["green", "blue"])
overlay = make_outline_overlay(rgb_data = rgb_image, predictions = predictions2)

# save MESMER outputs
output_dir = f'{out_folder}MESMER_outputs/{maxima_threshold}maxima_2_{interior_threshold}interior_2/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

skimage.io.imsave(output_dir + "seg_outline2.tiff", img_as_ubyte(overlay[0, ..., 0]), check_contrast = False) # segmentation outline
skimage.io.imsave(output_dir + "seg_overlay2.tiff", img_as_ubyte(overlay[0, ...]), check_contrast = False) # segmentation overlay (nuc + membrane + outline)
skimage.io.imsave(output_dir + "MESMER_mask2.tiff", predictions2[0, ..., 0], check_contrast = False) # MESMER mask

# %%
rgb_image = create_rgb_image(cropped_stack3, channel_colors = ["green", "blue"])
overlay = make_outline_overlay(rgb_data = rgb_image, predictions = predictions3)

# save MESMER outputs
output_dir = f'{out_folder}MESMER_outputs/{maxima_threshold}maxima_3_{interior_threshold}interior_3/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

skimage.io.imsave(output_dir + "seg_outline3.tiff", img_as_ubyte(overlay[0, ..., 0]), check_contrast = False) # segmentation outline
skimage.io.imsave(output_dir + "seg_overlay3.tiff", img_as_ubyte(overlay[0, ...]), check_contrast = False) # segmentation overlay (nuc + membrane + outline)
skimage.io.imsave(output_dir + "MESMER_mask3.tiff", predictions3[0, ..., 0], check_contrast = False) # MESMER mask

# %%
rgb_image = create_rgb_image(cropped_stack4, channel_colors = ["green", "blue"])
overlay = make_outline_overlay(rgb_data = rgb_image, predictions = predictions4)

# save MESMER outputs
output_dir = f'{out_folder}MESMER_outputs/{maxima_threshold}maxima_4_{interior_threshold}interior_4/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

skimage.io.imsave(output_dir + "seg_outline4.tiff", img_as_ubyte(overlay[0, ..., 0]), check_contrast = False) # segmentation outline
skimage.io.imsave(output_dir + "seg_overlay4.tiff", img_as_ubyte(overlay[0, ...]), check_contrast = False) # segmentation overlay (nuc + membrane + outline)
skimage.io.imsave(output_dir + "MESMER_mask4.tiff", predictions4[0, ..., 0], check_contrast = False) # MESMER mask

# %% [markdown]
# Pause here to validate that segmentation looks good, otherwise tune parameters until satisfied then proceed to feature extraction

# %% [markdown]
# ## Extract SC features

# %%
markers1 = ['DAPI', 'CD3', 'aSMA', 'CD15', 'CD4', 'CD8', 'CD11b', 'CD11c', 'CD20', 'CD21', 'H2K27me3', 'Ki.67', 'HLA.DRA', 'Histone.H3', 'CD68', 'DC.SIGN', 'Foxp3', 'PD.1', 'CD163', 'H3K27ac', 'Granzyme.B', 'CD31', 'CD206', 'CD138', 'NaK.ATPase', 'CD45RA', 'CD45', 'Cytokeratin']

# load in mask
mask1 = skimage.io.imread(f'{out_folder}MESMER_outputs/0.075maxima_1_0.2interior_1/MESMER_mask1.tiff')

# %%
print(f'Image stack shape: {slide1.shape}')
# Out:
# Image stack shape: (28, 21600, 26880)

# %%
# transpose the stack dimensions 
array_list = np.transpose(slide1, (1, 2, 0))
array_list.shape
# Out:
# (21600, 26880, 28)

# %%
# crop the array to match cropping done earlier
cropped_array_list = array_list[y_min1:y_max1, x_min1:x_max1, :]
cropped_array_list.shape
# Out:
# (5500, 7000, 28)

# %%
stats = skimage.measure.regionprops(mask1)
cell_count = len(stats) # number of actual cells not always equal to np.max(mask) 
marker_count = len(markers1)
print(f'Number of cells: {cell_count}')
# Out:
# Number of cells: 176468

# %%
# extract sc features from cropped_array_list
data, dataScaleSize, cell_props,cellSizes = extract_sc_features(cropped_array_list, mask=mask1, markers=markers1)
# Out:
# 100%|██████████| 176468/176468 [01:07<00:00, 2628.65it/s]

# %%
data_df = pd.DataFrame(data)
data_df.columns = markers1
data_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), data_df), axis=1)

dataScaleSize_df = pd.DataFrame(dataScaleSize)
dataScaleSize_df.columns = markers1
dataScaleSize_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), dataScaleSize_df), axis = 1)

# %%
data_full.head()
# Out:
#    cellLabel    Y_cent       X_cent  cellSize    DAPI    CD3   aSMA  CD15  \
# 0        1.0  1.866667   419.644444      45.0  5575.0   31.0  222.0   8.0
# 1        2.0  1.457143   495.028571      35.0  4705.0  155.0  118.0   3.0
# 2        3.0  1.193548   638.193548      31.0  6100.0   50.0  120.0  10.0
# 3        4.0  1.400000  1278.533333      30.0  2249.0   17.0   69.0   0.0
# 4        5.0  1.312500  2471.687500      32.0  4318.0  456.0  108.0   9.0
#
#       CD4    CD8  ...  CD163  H3K27ac  Granzyme.B   CD31  CD206  CD138  \
# 0  1924.0    3.0  ...  132.0    397.0       222.0   18.0   18.0  314.0
# 1  1973.0    7.0  ...  104.0    288.0       181.0   18.0   14.0  227.0
# 2  1449.0  174.0  ...   95.0    238.0       148.0   43.0   20.0  244.0
# 3  1602.0    3.0  ...   54.0    337.0       168.0  340.0   13.0  182.0
# 4  3054.0    3.0  ...   59.0    273.0       191.0    8.0   14.0  201.0
#
#    NaK.ATPase  CD45RA  CD45  Cytokeratin
# 0       519.0  2626.0  14.0       3821.0
# 1       845.0  1889.0   3.0       2981.0
# 2       389.0  1883.0   7.0       2635.0
# 3       585.0  1584.0   1.0       1606.0
# 4      1307.0  1613.0   6.0       2134.0
#
# [5 rows x 32 columns]

# %%
dataScaleSize_full.head()
# Out:
#    cellLabel    Y_cent       X_cent  cellSize        DAPI        CD3  \
# 0        1.0  1.866667   419.644444      45.0  123.888889   0.688889
# 1        2.0  1.457143   495.028571      35.0  134.428571   4.428571
# 2        3.0  1.193548   638.193548      31.0  196.774194   1.612903
# 3        4.0  1.400000  1278.533333      30.0   74.966667   0.566667
# 4        5.0  1.312500  2471.687500      32.0  134.937500  14.250000
#
#        aSMA      CD15        CD4       CD8  ...     CD163    H3K27ac  \
# 0  4.933333  0.177778  42.755556  0.066667  ...  2.933333   8.822222
# 1  3.371429  0.085714  56.371429  0.200000  ...  2.971429   8.228571
# 2  3.870968  0.322581  46.741935  5.612903  ...  3.064516   7.677419
# 3  2.300000  0.000000  53.400000  0.100000  ...  1.800000  11.233333
# 4  3.375000  0.281250  95.437500  0.093750  ...  1.843750   8.531250
#
#    Granzyme.B       CD31     CD206     CD138  NaK.ATPase     CD45RA      CD45  \
# 0    4.933333   0.400000  0.400000  6.977778   11.533333  58.355556  0.311111
# 1    5.171429   0.514286  0.400000  6.485714   24.142857  53.971429  0.085714
# 2    4.774194   1.387097  0.645161  7.870968   12.548387  60.741935  0.225806
# 3    5.600000  11.333333  0.433333  6.066667   19.500000  52.800000  0.033333
# 4    5.968750   0.250000  0.437500  6.281250   40.843750  50.406250  0.187500
#
#    Cytokeratin
# 0    84.911111
# 1    85.171429
# 2    85.000000
# 3    53.533333
# 4    66.687500
#
# [5 rows x 32 columns]

# %%
# save the dataframes
save_dir = f'{out_folder}extracted_features'

if not os.path.exists(save_dir):
    os.mkdir(save_dir)

data_full.to_csv(os.path.join(save_dir, 'data_slide1.csv'), index = False)
dataScaleSize_full.to_csv(os.path.join(save_dir, 'dataScaleSize_slide1.csv'), index = False)

# %%
markers2 = ['DAPI', 'CD3', 'aSMA', 'CD15', 'CD4', 'CD8', 'CD11b', 'CD11c', 'CD20', 'CD21', 'H2K27me3', 'Ki.67', 'HLA.DRA', 'Histone.H3', 'CD68', 'DC.SIGN', 'Foxp3', 'PD.1', 'CD163', 'H3K27ac', 'Granzyme.B', 'CD31', 'CD206', 'CD138', 'NaK.ATPase', 'CD45RA', 'CD45', 'Cytokeratin']

# load in mask
mask2 = skimage.io.imread(f'{out_folder}MESMER_outputs/0.075maxima_2_0.2interior_2/MESMER_mask2.tiff')

# %%
print(f'Image stack shape: {slide2.shape}')
# Out:
# Image stack shape: (28, 16560, 24960)

# %%
# transpose the stack dimensions 
array_list = np.transpose(slide2, (1, 2, 0))
array_list.shape
# Out:
# (16560, 24960, 28)

# %%
# crop the array to match cropping done earlier
cropped_array_list = array_list[y_min2:y_max2, x_min2:x_max2, :]
cropped_array_list.shape
# Out:
# (5500, 7000, 28)

# %%
stats = skimage.measure.regionprops(mask2)
cell_count = len(stats) # number of actual cells not always equal to np.max(mask) 
marker_count = len(markers2)
print(f'Number of cells: {cell_count}')
# Out:
# Number of cells: 173118

# %%
# extract sc features from cropped_array_list
data, dataScaleSize, cell_props,cellSizes = extract_sc_features(cropped_array_list, mask=mask2, markers=markers2)
# Out:
# 100%|██████████| 173118/173118 [01:06<00:00, 2604.31it/s]

# %%
data_df = pd.DataFrame(data)
data_df.columns = markers2
data_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), data_df), axis=1)

dataScaleSize_df = pd.DataFrame(dataScaleSize)
dataScaleSize_df.columns = markers2
dataScaleSize_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), dataScaleSize_df), axis = 1)

# %%
data_full.head()
# Out:
#    cellLabel    Y_cent       X_cent  cellSize    DAPI    CD3   aSMA  CD15  \
# 0        1.0  1.744681  2594.085106      47.0  8101.0  722.0  299.0  10.0
# 1        2.0  0.750000  3122.350000      20.0  3044.0   56.0  134.0   4.0
# 2        3.0  1.314286  3557.000000      35.0  5679.0  350.0  192.0  10.0
# 3        4.0  0.772727  3716.000000      22.0  3671.0  223.0  114.0   2.0
# 4        5.0  2.133333    26.733333      60.0  4953.0   51.0  163.0   3.0
#
#       CD4    CD8  ...  CD163  H3K27ac  Granzyme.B  CD31  CD206  CD138  \
# 0  3150.0   19.0  ...  125.0   1259.0        62.0  21.0   87.0  763.0
# 1   579.0    3.0  ...   38.0    451.0         8.0   4.0   19.0  329.0
# 2  1036.0  214.0  ...  117.0   1779.0        40.0  16.0   49.0  508.0
# 3   745.0   54.0  ...   58.0    520.0        33.0  12.0   35.0  331.0
# 4   658.0   21.0  ...  126.0    722.0        14.0  28.0   58.0  525.0
#
#    NaK.ATPase  CD45RA  CD45  Cytokeratin
# 0      1512.0   673.0   4.0       2985.0
# 1       582.0   855.0   1.0       1129.0
# 2       883.0   537.0   5.0       2164.0
# 3       597.0   310.0   1.0       1396.0
# 4       959.0  2090.0   5.0       3424.0
#
# [5 rows x 32 columns]

# %%
dataScaleSize_full.head()
# Out:
#    cellLabel    Y_cent       X_cent  cellSize        DAPI        CD3  \
# 0        1.0  1.744681  2594.085106      47.0  172.361702  15.361702
# 1        2.0  0.750000  3122.350000      20.0  152.200000   2.800000
# 2        3.0  1.314286  3557.000000      35.0  162.257143  10.000000
# 3        4.0  0.772727  3716.000000      22.0  166.863636  10.136364
# 4        5.0  2.133333    26.733333      60.0   82.550000   0.850000
#
#        aSMA      CD15        CD4       CD8  ...     CD163    H3K27ac  \
# 0  6.361702  0.212766  67.021277  0.404255  ...  2.659574  26.787234
# 1  6.700000  0.200000  28.950000  0.150000  ...  1.900000  22.550000
# 2  5.485714  0.285714  29.600000  6.114286  ...  3.342857  50.828571
# 3  5.181818  0.090909  33.863636  2.454545  ...  2.636364  23.636364
# 4  2.716667  0.050000  10.966667  0.350000  ...  2.100000  12.033333
#
#    Granzyme.B      CD31     CD206      CD138  NaK.ATPase     CD45RA      CD45  \
# 0    1.319149  0.446809  1.851064  16.234043   32.170213  14.319149  0.085106
# 1    0.400000  0.200000  0.950000  16.450000   29.100000  42.750000  0.050000
# 2    1.142857  0.457143  1.400000  14.514286   25.228571  15.342857  0.142857
# 3    1.500000  0.545455  1.590909  15.045455   27.136364  14.090909  0.045455
# 4    0.233333  0.466667  0.966667   8.750000   15.983333  34.833333  0.083333
#
#    Cytokeratin
# 0    63.510638
# 1    56.450000
# 2    61.828571
# 3    63.454545
# 4    57.066667
#
# [5 rows x 32 columns]

# %%
# save the dataframes
save_dir = f'{out_folder}extracted_features'

if not os.path.exists(save_dir):
    os.mkdir(save_dir)

data_full.to_csv(os.path.join(save_dir, 'data_slide2.csv'), index = False)
dataScaleSize_full.to_csv(os.path.join(save_dir, 'dataScaleSize_slide2.csv'), index = False)

# %%
markers3 = ['DAPI', 'CD3', 'aSMA', 'CD15', 'CD4', 'CD8', 'CD11b', 'CD11c', 'CD20', 'CD21', 'H2K27me3', 'Ki.67', 'HLA.DRA', 'Histone.H3', 'CD68', 'DC.SIGN', 'Foxp3', 'PD.1', 'CD163', 'H3K27ac', 'Granzyme.B', 'CD31', 'CD206', 'CD138', 'NaK.ATPase', 'CD45RA', 'CD45', 'Cytokeratin']

# load in mask
mask3 = skimage.io.imread(f'{out_folder}MESMER_outputs/0.075maxima_3_0.2interior_3/MESMER_mask3.tiff')

# %%
print(f'Image stack shape: {slide3.shape}')
# Out:
# Image stack shape: (28, 25200, 33600)

# %%
# transpose the stack dimensions 
array_list = np.transpose(slide3, (1, 2, 0))
array_list.shape
# Out:
# (25200, 33600, 28)

# %%
# crop the array to match cropping done earlier
cropped_array_list = array_list[y_min3:y_max3, x_min3:x_max3, :]
cropped_array_list.shape
# Out:
# (5500, 7000, 28)

# %%
stats = skimage.measure.regionprops(mask3)
cell_count = len(stats) # number of actual cells not always equal to np.max(mask) 
marker_count = len(markers3)
print(f'Number of cells: {cell_count}')
# Out:
# Number of cells: 179937

# %%
# extract sc features from cropped_array_list
data, dataScaleSize, cell_props,cellSizes = extract_sc_features(cropped_array_list, mask=mask3, markers=markers3)
# Out:
# 100%|██████████| 179937/179937 [01:05<00:00, 2727.11it/s]

# %%
data_df = pd.DataFrame(data)
data_df.columns = markers3
data_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), data_df), axis=1)

dataScaleSize_df = pd.DataFrame(dataScaleSize)
dataScaleSize_df.columns = markers3
dataScaleSize_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), dataScaleSize_df), axis = 1)

# %%
data_full.head()
# Out:
#    cellLabel    Y_cent       X_cent  cellSize    DAPI    CD3   aSMA  CD15  \
# 0        1.0  1.000000  2992.136364      22.0  2626.0   31.0   82.0   8.0
# 1        2.0  1.818182    69.151515      66.0  5955.0   20.0  176.0   4.0
# 2        3.0  1.244444   721.911111      45.0  5875.0   12.0  157.0   3.0
# 3        4.0  1.400000  2445.966667      30.0  5884.0  201.0  160.0   2.0
# 4        5.0  1.700000  3227.120000      50.0  7253.0  144.0  179.0  14.0
#
#       CD4   CD8  ...  CD163  H3K27ac  Granzyme.B  CD31  CD206  CD138  \
# 0   355.0  23.0  ...   59.0    241.0        23.0  17.0   43.0  214.0
# 1   382.0  14.0  ...  175.0    610.0        22.0  30.0   62.0  699.0
# 2   220.0   6.0  ...  149.0    804.0         9.0  36.0   30.0  357.0
# 3   937.0  29.0  ...  136.0    867.0        15.0   9.0   29.0  314.0
# 4  1265.0   7.0  ...  132.0    647.0        23.0  12.0   69.0  442.0
#
#    NaK.ATPase  CD45RA  CD45  Cytokeratin
# 0       301.0  1136.0   6.0       1098.0
# 1       742.0  3272.0  23.0       3051.0
# 2       445.0  2064.0  11.0       2575.0
# 3       599.0   665.0  16.0       2521.0
# 4      1330.0  2068.0  25.0       2842.0
#
# [5 rows x 32 columns]

# %%
dataScaleSize_full.head()
# Out:
#    cellLabel    Y_cent       X_cent  cellSize        DAPI       CD3      aSMA  \
# 0        1.0  1.000000  2992.136364      22.0  119.363636  1.409091  3.727273
# 1        2.0  1.818182    69.151515      66.0   90.227273  0.303030  2.666667
# 2        3.0  1.244444   721.911111      45.0  130.555556  0.266667  3.488889
# 3        4.0  1.400000  2445.966667      30.0  196.133333  6.700000  5.333333
# 4        5.0  1.700000  3227.120000      50.0  145.060000  2.880000  3.580000
#
#        CD15        CD4       CD8  ...     CD163    H3K27ac  Granzyme.B  \
# 0  0.363636  16.136364  1.045455  ...  2.681818  10.954545    1.045455
# 1  0.060606   5.787879  0.212121  ...  2.651515   9.242424    0.333333
# 2  0.066667   4.888889  0.133333  ...  3.311111  17.866667    0.200000
# 3  0.066667  31.233333  0.966667  ...  4.533333  28.900000    0.500000
# 4  0.280000  25.300000  0.140000  ...  2.640000  12.940000    0.460000
#
#        CD31     CD206      CD138  NaK.ATPase     CD45RA      CD45  Cytokeratin
# 0  0.772727  1.954545   9.727273   13.681818  51.636364  0.272727    49.909091
# 1  0.454545  0.939394  10.590909   11.242424  49.575758  0.348485    46.227273
# 2  0.800000  0.666667   7.933333    9.888889  45.866667  0.244444    57.222222
# 3  0.300000  0.966667  10.466667   19.966667  22.166667  0.533333    84.033333
# 4  0.240000  1.380000   8.840000   26.600000  41.360000  0.500000    56.840000
#
# [5 rows x 32 columns]

# %%
# save the dataframes
save_dir = f'{out_folder}extracted_features'

if not os.path.exists(save_dir):
    os.mkdir(save_dir)

data_full.to_csv(os.path.join(save_dir, 'data_slide3.csv'), index = False)
dataScaleSize_full.to_csv(os.path.join(save_dir, 'dataScaleSize_slide3.csv'), index = False)

# %%
markers4 = ['DAPI', 'CD3', 'aSMA', 'CD15', 'CD4', 'CD8', 'CD11b', 'CD11c', 'CD20', 'CD21', 'H2K27me3', 'Ki.67', 'HLA.DRA', 'Histone.H3', 'CD68', 'DC.SIGN', 'Foxp3', 'PD.1', 'CD163', 'H3K27ac', 'Granzyme.B', 'CD31', 'CD206', 'CD138', 'NaK.ATPase', 'CD45RA', 'CD45', 'Cytokeratin']

# load in mask
mask4 = skimage.io.imread(f'{out_folder}MESMER_outputs/0.075maxima_4_0.2interior_4/MESMER_mask4.tiff')

# %%
print(f'Image stack shape: {slide4.shape}')
# Out:
# Image stack shape: (28, 22320, 25920)

# %%
# transpose the stack dimensions 
array_list = np.transpose(slide4, (1, 2, 0))
array_list.shape
# Out:
# (22320, 25920, 28)

# %%
# crop the array to match cropping done earlier
cropped_array_list = array_list[y_min4:y_max4, x_min4:x_max4, :]
cropped_array_list.shape
# Out:
# (5500, 7000, 28)

# %%
stats = skimage.measure.regionprops(mask4)
cell_count = len(stats) # number of actual cells not always equal to np.max(mask) 
marker_count = len(markers4)
print(f'Number of cells: {cell_count}')
# Out:
# Number of cells: 173680

# %%
# extract sc features from cropped_array_list
data, dataScaleSize, cell_props,cellSizes = extract_sc_features(cropped_array_list, mask=mask4, markers=markers4)
# Out:
#  41%|████      | 70997/173680 [00:26<00:38, 2694.23it/s]

# %%
# extract info
for i in tqdm(range(cell_count)): # tqdm creates the progress bar
    cellLabel = stats[i].label
    label_counts = [cropped_array_list[coord[0], coord[1], :] for coord in stats[i].coords] # all markers for this cell
    data[i, 0:marker_count] = np.sum(label_counts, axis = 0) # sum the marker expression for this cell
    dataScaleSize[i, 0:marker_count] = np.sum(label_counts, axis = 0) / stats[i].area # scale the sum by size
    cellSizes[i] = stats[i].area # cell size
    cell_props[i, 0] = cellLabel
    cell_props[i, 1] = stats[i].centroid[0] # Y centroid
    cell_props[i, 2] = stats[i].centroid[1] # X centroid

# %%
data_df = pd.DataFrame(data)
data_df.columns = markers4
data_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), data_df), axis=1)

dataScaleSize_df = pd.DataFrame(dataScaleSize)
dataScaleSize_df.columns = markers4
dataScaleSize_full = pd.concat((pd.DataFrame(cell_props, columns = ["cellLabel", "Y_cent", "X_cent"]), pd.DataFrame(cellSizes, columns = ["cellSize"]), dataScaleSize_df), axis = 1)

# %%
data_full.head()

# %%
dataScaleSize_full.head()

# %%
# save the dataframes
save_dir = f'{out_folder}extracted_features'

if not os.path.exists(save_dir):
    os.mkdir(save_dir)

data_full.to_csv(os.path.join(save_dir, 'data_slide4.csv'), index = False)
dataScaleSize_full.to_csv(os.path.join(save_dir, 'dataScaleSize_slide4.csv'), index = False)
